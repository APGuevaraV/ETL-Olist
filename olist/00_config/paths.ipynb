# %%
# ==============================
# Storage base
# ==============================
STORAGE_ACCOUNT = "adlsolistdev"
CONTAINER_LANDING = "landing"
CONTAINER_BRONZE = "bronze"
CONTAINER_SILVER = "silver"
CONTAINER_GOLD = "golden"

FOLDER = "olist"

BASE_LANDING_PATH = f"abfss://{CONTAINER_LANDING}@{STORAGE_ACCOUNT}.dfs.core.windows.net"
BASE_BRONZE_PATH = f"abfss://{CONTAINER_BRONZE}@{STORAGE_ACCOUNT}.dfs.core.windows.net"
BASE_SILVER_PATH = f"abfss://{CONTAINER_SILVER}@{STORAGE_ACCOUNT}.dfs.core.windows.net"
BASE_GOLD_PATH = f"abfss://{CONTAINER_GOLD}@{STORAGE_ACCOUNT}.dfs.core.windows.net"

# ==============================
# OLIST – Bronze
# ==============================
BRONZE_ORDERS_PATH = f"{BASE_BRONZE_PATH}/{FOLDER}/olist_orders"
BRONZE_ORDER_ITEMS_PATH = f"{BASE_BRONZE_PATH}/{FOLDER}/olist_order_items"
BRONZE_ORDER_PAYMENTS_PATH = f"{BASE_BRONZE_PATH}/{FOLDER}/olist_order_payments"
BRONZE_ORDER_REVIEWS_PATH = f"{BASE_BRONZE_PATH}/{FOLDER}/olist_order_reviews"
BRONZE_CUSTOMERS_PATH = f"{BASE_BRONZE_PATH}/{FOLDER}/olist_customers"
BRONZE_PRODUCTS_PATH = f"{BASE_BRONZE_PATH}/{FOLDER}/olist_products"
BRONZE_SELLERS_PATH = f"{BASE_BRONZE_PATH}/{FOLDER}/olist_sellers"
BRONZE_GEOLOCATION_PATH = f"{BASE_BRONZE_PATH}/{FOLDER}/olist_geolocation"
BRONZE_CATEGORY_TRANSLATION_PATH = f"{BASE_BRONZE_PATH}/{FOLDER}/product_category_name_translation"

# ==============================
# OLIST – Silver
# ==============================
SILVER_ORDERS_PATH = f"{BASE_SILVER_PATH}/{FOLDER}/olist_orders"
SILVER_ORDER_ITEMS_PATH = f"{BASE_SILVER_PATH}/{FOLDER}/olist_order_items"
SILVER_ORDER_PAYMENTS_PATH = f"{BASE_SILVER_PATH}/{FOLDER}/olist_order_payments"
SILVER_ORDER_REVIEWS_PATH = f"{BASE_SILVER_PATH}/{FOLDER}/olist_order_reviews"
SILVER_CUSTOMERS_PATH = f"{BASE_SILVER_PATH}/{FOLDER}/olist_customers"
SILVER_PRODUCTS_PATH = f"{BASE_SILVER_PATH}/{FOLDER}/olist_products"
SILVER_SELLERS_PATH = f"{BASE_SILVER_PATH}/{FOLDER}/olist_sellers"
SILVER_GEOLOCATION_PATH = f"{BASE_SILVER_PATH}/{FOLDER}/olist_geolocation"
SILVER_CATEGORY_TRANSLATION_PATH = f"{BASE_SILVER_PATH}/{FOLDER}/product_category_name_translation"

# ==============================
# OLIST – GOLD
# ==============================

GOLD_PATH = f"{BASE_GOLD_PATH}/{FOLDER}/olist_analytics"
