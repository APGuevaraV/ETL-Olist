# %%
# ======================================
# Dataset: product_category_name_translation
# Layer: Silver
# Source: Bronze (Delta)
# Grain: 1 row per product_category_name
# ======================================

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import *
from pyspark.sql.window import Window

# %%
# %run ../commons/silver_utils

# %%
# %run ../../00_config/paths

# %%
df_bronze = spark.read.format("delta").load(BRONZE_CATEGORY_TRANSLATION_PATH)

# %%
df= normalize_columns(df_bronze)

# %%
df = (
    df
    .withColumn("product_category_name", F.trim(F.lower(F.col("product_category_name"))))
    .withColumn("product_category_name_english", F.trim(F.lower(F.col("product_category_name_english"))))
)

# %%
df = df.filter(
    F.col("product_category_name").isNotNull() &
    F.col("product_category_name_english").isNotNull()
)

# %%
df = df.filter(
    (F.length(F.col("product_category_name")) > 0) &
    (F.length(F.col("product_category_name_english")) > 0)
)

# %%
df.printSchema()

# %%
write_silver(df, SILVER_CATEGORY_TRANSLATION_PATH)
